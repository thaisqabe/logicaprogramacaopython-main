# %% [markdown]
# <a href="https://colab.research.google.com/github/thaisqabe/logicaprogramacaopython/blob/main/exercicosfluxogramatm/excercicoscomfluxograma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lista de exercícios

# %% [markdown]
# ## média entre duas notas
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
#entrada
p1 = float(input("Digite a primeira nota entre 0 e 10: "))
p2 = float(input("Digite a segunda nota entre 0 e 10: "))

#processamento
media = (p1+p2)/2

#saida
print("A média das notas é:", media)
# Out:
# Digite a primeira nota entre 0 e 10: 7
# Digite a segunda nota entre 0 e 10: 10
# A média das notas é: 8.5

# %% [markdown]
# ## coversão dólar
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
#entrada
dolar = 4.15
valorconvert = float(input("Digite o valor que voê quer converter: "))

#processamento
valorfinal=valorconvert/dolar

#saida
print("O valor convertido é:", valorfinal)
# Out:
# Digite o valor que voê quer converter: 138
# O valor convertido é: 33.253012048192765

# %% [markdown]
# ## cálculo
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
#entrada
2, 4, 5, 6

#processamento
calc = 2**2+4**2+5**2+6**2

#saida
print("O resultado do cálculo é:", calc)
# Out:
# O resuldato do cálculo é: 81

# %% [markdown]
# ## valor de peças vendidas e comissão
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
#entrada
pu=float(input("Digite o valor de cada peça: "))
qv=float(input("Digite quantas peças foram compradas: "))

#processamento
vtp = pu*qv
comi = (vtp*5)/100

#saida
print("O valor total das vendas foi:", vtp)
print("O valor da comissão é:", comi)
# Out:
# Digite o valor de cada peça: 7
# Digite quantas peças foram compradas: 55
# O valor total das vendas foi: 385.0
# O valor da comissão é: 19.25

# %% [markdown]
# ## valor final do carro
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
#entrada
vf=float(input("Digite o valor do carro: "))

#processamento
vfc=((vf*45)/100)+(vf)
vtotal=((vfc*28)/100)+(vfc)

#saida
print("O valor total do carro com o imposto e a porcentagem do distribuidor é:", vtotal)
# Out:
# Digite o valor do carro: 44420
# O valor total do carro com o imposto e a porcentagem do distribuidor é: 82443.52

# %% [markdown]
# ## horas e minutos convertidos
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
#entrada
h=(float(input("Digite a hora: ")))
m=(float(input("Digite os minutos: ")))

#processamento
mconvert=m/60
res=mconvert+h

#saida
print("As horas e minutos convertidos ficam:", res)
# Out:
# Digite a hora: 1
# Digite os minutos: 32
# As horas e minutos convertidos ficam: 1.5333333333333332

# %% [markdown]
# ## valor com horas extras
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
#entrada
ht=float(input("Digite a quantidade de horas trabalhadas: "))
mt=float(input("Digite a quantidade de minutos trabalhados: "))
qgt=float(input("Digite quanto você ganha por hora: "))

#processamento
htc=mt/60+ht
gtotal=qgt*htc
gthe=((gtotal*70)/100)+gtotal

#saida
print("O valor que você irá receber com as horas extras é:", gthe)
# Out:
# Digite a quantidade de horas trabalhadas: 40
# Digite a quantidade de minutos trabalhados: 40
# Digite quanto você ganha por hora: 50
# O valor que você irá receber com as horas extras é: 3456.666666666666

# %% [markdown]
# ## dinheiro gasto com gasolina na viagem
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
#entrada
kp=float(input("Digite quantos quilômetros você irá percorrer: "))
cg=float(input("Digite quantos quilômetros você percorre com 1 litro de gasolina: "))
pg=float(input("Digite quanto você paga em 1 litro de gasolina: "))

#processamento
lg=kp/cg
pfinal=lg*pg

#saida
print("O valor que você gastará com gasolina na ida da sua viagem será:", pfinal)
# Out:
# Digite quantos quilômetros você irá percorrer: 650
# Digite quantos quilômetros você percorre com 1 litro de gasolina: 10
# Digite quanto você paga em 1 litro de gasolina: 6.50
# O valor que você gastará com gasolina na ida da sua viagem será: 422.5

# %% [markdown]
# ## velocidade média de um carro
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
#entrada
ppkm=float(input("Digite o percurso percorrido em quilômetros: "))
hgp=float(input("Digite as horas gastas no percurso: "))
mgp=float(input("Digite os minutos gastos no percurso: "))

#processamento
tpg=mgp/60+hgp
vm=ppkm/tpg

#saida
print("A velocidade média em km/h é: ", vm)
# Out:
# Digite o percurso percorrido em quilômetros: 570
# Digite as horas gastas no percurso: 4
# Digite os minutos gastos no percurso: 50
# A velocidade média em km/h é:  117.93103448275863
